# %%
import numpy as np

A = np.array([[2, 1],
              [1, -1]])
A
# Out:
# array([[ 2,  1],
#        [ 1, -1]])

# %%
# Rows = people, columns = [notebooks, pens]
M = np.array([
    [15, 6],   # Radha
    [10, 2],   # Fauzia
    [13, 5]    # Simran
])
M
# Out:
# array([[15,  6],
#        [10,  2],
#        [13,  5]])
