# %%
import numpy as np

A = np.array([[2, 1],
              [1, -1]])
A
# Out:
# array([[ 2,  1],
#        [ 1, -1]])

# %%
# Rows = people, columns = [notebooks, pens]
M = np.array([
    [15, 6],   # Radha
    [10, 2],   # Fauzia
    [13, 5]    # Simran
])
M
# Out:
# array([[15,  6],
#        [10,  2],
#        [13,  5]])

# %%
s1 = 'Python'
s2 = 'Programming'
s3 = """line1
line2"""

# %%
s3
# Out:
# 'line1\nline2'
